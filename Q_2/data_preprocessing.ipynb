# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
# read the data with column names category, text
df = pd.read_csv(r'Data\all-data.csv', encoding='ISO-8859-1', names=['category', 'text'])

# %%
df.head()
# Out:
#    category                                               text
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %% [markdown]
# ### 1. Preprocessing

# %%
from nltk.corpus import stopwords
stopwords = stopwords.words('english')
stopwords = set(stopwords)
 
def remove_punctuation(text):
    import string
    new_string = ""
    for char in text:
        if char not in string.punctuation:
            new_string += char
    return new_string

def remove_stopwords(text):
    
    new_string = ""
    for word in text.split():
        if word not in stopwords:
            new_string += word + " "
    return new_string

def lower_case(text):
    return text.lower()

def tokenize(text):
    return text.split()

def lemmatize(text):
    from nltk.stem import WordNetLemmatizer
    lemmatizer = WordNetLemmatizer()
    new_string = []
    for word in text:
        new_string.append(lemmatizer.lemmatize(word))
    return new_string

# %%
df['text'] = df['text'].apply(remove_punctuation)
df['text'] = df['text'].apply(lower_case)
df['text'] = df['text'].apply(remove_stopwords)

# %%
df['text'] = df['text'].apply(tokenize)
df['text'] = df['text'].apply(lemmatize)

# %%
class TF_ICF:
    def __init__(self, classes, ls_text, ls_classes):
        self.classes = classes
        self.ls_text = ls_text
        self.ls_classes = ls_classes
        self.tf = {}
        self.cf = {}
        self.icf = {}
        self.tf_icf = {}
        self.build()
        
    def build(self):
        for class_ in self.classes:
            self.tf[class_] = {}
            self.build_tf(class_)
        self.build_cf()
        self.build_icf()
    
    def build_tf(self, class_):
        filtered_text = [self.ls_text[i] for i in range(len(self.ls_text)) if self.ls_classes[i] == class_]
        for text in filtered_text:
            for word in text:
                if word not in self.tf[class_]:
                    self.tf[class_][word] = 0
                self.tf[class_][word] += 1

    def build_cf(self):
        for i in range(len(self.ls_text)):
            current_class = self.ls_classes[i]
            for word in self.ls_text[i]:
                if word not in self.cf:
                    self.cf[word] = set()
                self.cf[word].add(current_class)
        # replce set with length of set
        for word in self.cf:
            self.cf[word] = len(self.cf[word])
    
    def build_icf(self):
        for word in self.cf:
            self.icf[word] = np.log(len(self.classes)/self.cf[word])

    def build_tf_icf(self):

# %%
tf_icf = TF_ICF(set(df['category']), df['text'], df['category'])

# %%
tf_icf.icf
# Out:
# {'according': 0.0,
#  'gran': 0.4054651081081644,
#  'company': 0.0,
#  'plan': 0.0,
#  'move': 0.0,
#  'production': 0.0,
#  'russia': 0.0,
#  'although': 0.4054651081081644,
#  'growing': 0.4054651081081644,
#  'technopolis': 0.4054651081081644,
#  'develop': 0.4054651081081644,
#  'stage': 0.4054651081081644,
#  'area': 0.0,
#  'le': 0.0,
#  '100000': 1.0986122886681098,
#  'square': 1.0986122886681098,
#  'meter': 1.0986122886681098,
#  'order': 0.0,
#  'host': 1.0986122886681098,
#  'working': 0.0,
#  'computer': 0.0,
#  'technology': 0.0,
#  'telecommunication': 0.0,
#  'statement': 0.4054651081081644,
#  'said': 0.0,
#  'international': 0.0,
#  'electronic': 0.0,
#  'industry': 0.0,
#  'elcoteq': 0.0,
#  'laid': 1.0986122886681098,
#  'ten': 0.0,
#  'employee': 0.0,
#  'tallinn': 0.0,
#  'facility': 0.0,
#  'contrary': 1.0986122886681098,
#  'earlier': 0.0,
#  'layoff': 0.0,
#  'contracted': 0.4054651081081644,
#  'rank': 0.4054651081081644,
#  'office': 0.0,
#  'worker': 0.0,
#  'daily': 0.0,
#  'postimees': 1.0986122886681098,
#  'reported': 0.0,
#  'new': 0.0,
#  'plant': 0.0,
#  'would': 0.0,
#  'increase': 0.0,
#  'capacity': 0.0,
#  'meet': 0.4054651081081644,
#  'expected': 0.0,
#  'demand': 0.0,
#  'improve': 0.4054651081081644,
#  'use': 0.0,
#  'raw': 0.0,
#  'material': 0.0,
#  'therefore': 0.0,
#  'profitability': 0.0,
#  'updated': 0.4054651081081644,
#  'strategy': 0.4054651081081644,
#  'year': 0.0,
#  '20092012': 1.0986122886681098,
#  'basware': 0.0,
#  'target': 0.0,
#  'longterm': 0.0,
#  'net': 0.0,
#  'sale': 0.0,
#  'growth': 0.0,
#  'range': 0.4054651081081644,
#  '20': 0.0,
#  '40': 0.0,
#  'operating': 0.0,
#  'profit': 0.0,
#  'margin': 0.0,
#  '10': 0.0,
#  'financing': 0.0,
#  'aspocomp': 0.0,
#  'aggressively': 1.0986122886681098,
#  'pursuing': 1.0986122886681098,
#  'increasingly': 0.0,
#  'focusing': 0.4054651081081644,
#  'technologically': 1.0986122886681098,
#  'demanding': 0.0,
#  'hdi': 1.0986122886681098,
#  'printed': 0.4054651081081644,
#  'circuit': 0.4054651081081644,
#  'board': 0.0,
#  'pcbs': 0.4054651081081644,
#  'last': 0.0,
#  'quarter': 0.0,
#  '2010': 0.0,
#  'componenta': 0.0,
#  'doubled': 1.0986122886681098,
#  'eur131m': 1.0986122886681098,
#  'eur76m': 1.0986122886681098,
#  'period': 0.0,
#  'moved': 0.4054651081081644,
#  'zero': 1.0986122886681098,
#  'pretax': 0.0,
#  'loss': 0.0,
#  'eur7m': 1.0986122886681098,
#  'third': 0.0,
#  'increased': 0.0,
#  '52': 0.0,
#  'eur': 0.0,
#  '2055': 1.0986122886681098,
#  'mn': 0.0,
#  '349': 1.0986122886681098,
#  '235': 0.0,
#  'rose': 0.0,
#  '131': 0.0,
#  '87': 0.0,
#  'corresponding': 0.0,
#  '2007': 0.0,
#  'representing': 0.0,
#  '77': 0.4054651081081644,
#  'totalled': 0.0,
#  '211': 0.4054651081081644,
#  '186': 0.4054651081081644,
#  '97': 0.4054651081081644,
#  'teliasonera': 0.0,
#  'tlsn': 0.4054651081081644,
#  'offer': 0.0,
#  'line': 0.0,
#  'ownership': 0.4054651081081644,
#  'core': 0.4054651081081644,
#  'business': 0.0,
#  'holding': 0.0,
#  'strengthen': 0.4054651081081644,
#  'eesti': 0.4054651081081644,
#  'telekom': 1.0986122886681098,
#  'offering': 0.0,
#  'customer': 0.0,
#  'stora': 0.0,
#  'enso': 0.0,
#  'norske': 0.0,
#  'skog': 0.0,
#  'mreal': 0.0,
#  'upmkymmene': 0.0,
#  'credit': 0.4054651081081644,
#  'suisse': 0.4054651081081644,
#  'first': 0.0,
#  'boston': 1.0986122886681098,
#  'cfsb': 1.0986122886681098,
#  'raised': 0.0,
#  'fair': 0.0,
#  'value': 0.0,
#  'share': 0.0,
#  'four': 0.0,
#  'largest': 0.0,
#  'nordic': 0.0,
#  'forestry': 0.0,
#  'group': 0.0,
#  'purchase': 0.0,
#  'agreement': 0.0,
#  '7200': 1.0986122886681098,
#  'ton': 0.0,
#  'gasoline': 0.4054651081081644,
#  'delivery': 0.0,
#  'hamina': 0.4054651081081644,
#  'terminal': 0.0,
#  'finland': 0.0,
#  'signed': 0.4054651081081644,
#  'neste': 0.0,
#  'oil': 0.0,
#  'oyj': 0.0,
#  'average': 0.0,
#  'platts': 1.0986122886681098,
#  'index': 0.0,
#  'september': 0.0,
#  'plus': 0.4054651081081644,
#  'eight': 0.0,
#  'u': 0.0,
#  'dollar': 0.0,
#  'per': 0.0,
#  'month': 0.0,
#  'finnish': 0.0,
#  'talentum': 0.0,
#  'report': 0.0,
#  '205': 0.0,
#  '2005': 0.0,
#  '93': 0.0,
#  '2004': 0.0,
#  'totaled': 0.0,
#  '1033': 0.4054651081081644,
#  '964': 1.0986122886681098,
#  'clothing': 0.0,
#  'retail': 0.0,
#  'chain': 0.0,
#  'seppælæ': 1.0986122886681098,
#  '8': 0.0,
#  '1552': 0.4054651081081644,
#  '311': 0.4054651081081644,
#  '171': 0.4054651081081644,
#  'consolidated': 0.0,
#  '16': 0.0,
#  'reach': 0.4054651081081644,
#  'eur74': 1.0986122886681098,
#  'amounted': 0.0,
#  'eur0': 0.0,
#  '9': 0.0,
#  'compared': 0.0,
#  '7': 0.0,
#  'prior': 0.4054651081081644,
#  'foundry': 0.0,
#  'division': 0.0,
#  '631': 1.0986122886681098,
#  '575': 0.4054651081081644,
#  '2006': 0.0,
#  'machine': 0.0,
#  'shop': 0.0,
#  '164': 0.4054651081081644,
#  '412': 1.0986122886681098,
#  '354': 0.0,
#  'helsinki': 0.0,
#  'afx': 0.0,
#  'closed': 0.0,
#  'higher': 0.0,
#  'led': 0.4054651081081644,
#  'nokia': 0.0,
#  'announced': 0.0,
#  'team': 0.0,
#  'sanyo': 1.0986122886681098,
#  'manufacture': 0.0,
#  '3g': 0.0,
#  'handset': 0.4054651081081644,
#  'nokian': 0.4054651081081644,
#  'tyre': 0.4054651081081644,
#  'fourthquarter': 0.4054651081081644,
#  'earnings': 0.0,
#  'beat': 1.0986122886681098,
#  'analyst': 0.0,
#  'expectation': 0.4054651081081644,
#  'dealer': 0.0,
#  'incap': 0.0,
#  'contract': 0.0,
#  'manufacturing': 0.0,
#  'service': 0.0,
#  'pvt': 0.4054651081081644,
#  'ltd': 0.0,
#  'subsidiary': 0.0,
#  'corporation': 0.0,
#  'double': 0.4054651081081644,
#  'revenue': 0.0,
#  '20072008': 0.4054651081081644,
#  'director': 0.0,
#  'propose': 0.0,
#  'dividend': 0.4054651081081644,
#  '12': 0.0,
#  '08': 0.0,
#  'paid': 0.4054651081081644,
#  '2009': 0.0,
#  'lifetree': 0.4054651081081644,
#  'founded': 0.4054651081081644,
#  '2000': 0.0,
#  'risen': 1.0986122886681098,
#  'late': 0.4054651081081644,
#  '30': 0.0,
#  'filippova': 1.0986122886681098,
#  'trilateral': 1.0986122886681098,
#  'investment': 0.0,
#  'construction': 0.0,
#  'park': 0.4054651081081644,
#  'st': 0.0,
#  'petersburg': 0.0,
#  'course': 0.4054651081081644,
#  'forum': 1.0986122886681098,
#  'day': 0.0,
#  'russian': 0.0,
#  'economy': 0.0,
#  'opened': 0.4054651081081644,
#  'today': 0.0,
#  'megafon': 0.4054651081081644,
#  'subscriber': 0.4054651081081644,
#  'base': 0.4054651081081644,
#  '161': 0.4054651081081644,
#  '505': 1.0986122886681098,
#  'million': 0.0,
#  'user': 0.0,
#  'december': 0.0,
#  '31': 0.0,
#  'market': 0.0,
#  'number': 0.0,
#  '24': 0.0,
#  '23': 0.0,
#  '2008': 0.0,
#  'estimate': 0.0,
#  'income': 0.0,
#  'life': 0.0,
#  'insurance': 0.0,
#  '68': 0.4054651081081644,
#  '32': 0.0,
#  'nonlife': 0.4054651081081644,
#  '15': 0.0,
#  'eur193': 1.0986122886681098,
#  '3': 0.0,
#  'eur179': 1.0986122886681098,
#  '342': 1.0986122886681098,
#  'eur43': 1.0986122886681098,
#  '1': 0.0,
#  'eur1': 0.0,
#  'usd1': 0.4054651081081644,
#  '4': 0.0,
#  'surged': 0.4054651081081644,
#  '185': 0.4054651081081644,
#  'eur167': 1.0986122886681098,
#  'teleste': 0.0,
#  'eur20': 0.4054651081081644,
#  '122': 0.0,
#  'came': 0.0,
#  'acquisition': 0.0,
#  'made': 0.0,
#  'nordea': 0.0,
#  '18': 0.0,
#  'percent': 0.0,
#  'yearonyear': 0.4054651081081644,
#  '364': 1.0986122886681098,
#  'billion': 0.0,
#  'euro': 0.0,
#  'total': 0.0,
#  '933': 1.0986122886681098,
#  'ninemonth': 0.4054651081081644,
#  'eur13': 0.4054651081081644,
#  '6': 0.0,
#  'eur394': 1.0986122886681098,
#  'eur3': 0.0,
#  'eur61': 1.0986122886681098,
#  '5': 0.0,
#  'threemonth': 0.4054651081081644,
#  '2': 0.0,
#  'brazilian': 0.4054651081081644,
#  'unit': 0.0,
#  'security': 0.0,
#  'solution': 0.0,
#  'provider': 0.0,
#  'fsecure': 0.0,
#  '1500': 0.4054651081081644,
#  'client': 0.4054651081081644,
#  'online': 0.4054651081081644,
#  'news': 0.0,
#  'source': 0.0,
#  'reseller': 1.0986122886681098,
#  'web': 0.0,
#  'quoted': 0.4054651081081644,
#  'commercial': 0.0,
#  'vladimir': 0.4054651081081644,
#  'brando': 1.0986122886681098,
#  'saying': 0.0,
#  '114': 0.0,
#  '822': 1.0986122886681098,
#  '6865': 1.0986122886681098,
#  '138': 0.4054651081081644,
#  'lithuanian': 1.0986122886681098,
#  'beer': 0.0,
#  '1441': 1.0986122886681098,
#  'liter': 0.0,
#  'january': 0.0,
#  'rise': 0.4054651081081644,
#  'yearearlier': 0.4054651081081644,
#  'figure': 0.0,
#  'brewer': 0.4054651081081644,
#  'association': 0.0,
#  'reporting': 0.0,
#  'citing': 0.4054651081081644,
#  'result': 0.0,
#  'member': 0.0,
#  'viking': 0.0,
#  'cargo': 0.0,
#  '54': 0.0,
#  '2146': 1.0986122886681098,
#  'volume': 0.0,
#  '70116': 1.0986122886681098,
#  'property': 0.0,
#  'portfolio': 0.0,
#  'kapiteeli': 1.0986122886681098,
#  '26862': 1.0986122886681098,
#  '12597': 1.0986122886681098,
#  'february': 0.0,
#  '2011': 0.0,
#  'medium': 0.0,
#  'sanoma': 0.0,
#  'hel': 0.0,
#  'saa1v': 0.4054651081081644,
#  'yesterday': 0.0,
#  'almost': 0.0,
#  'tripled': 1.0986122886681098,
#  'eur297': 1.0986122886681098,
#  'eur107': 1.0986122886681098,
#  'proposal': 0.4054651081081644,
#  'payout': 1.0986122886681098,
#  'eliiv': 1.0986122886681098,
#  'eps': 0.0,
#  '13': 0.0,
#  'aspo': 0.4054651081081644,
#  'plc': 0.0,
#  'stock': 0.0,
#  'exchange': 0.0,
#  'release': 0.0,
#  '11': 0.0,
#  'at8': 1.0986122886681098,
#  '45': 0.0,
#  'esl': 0.4054651081081644,
#  'shipping': 0.0,
#  'part': 0.0,
#  'rautaruukki': 0.0,
#  'marine': 0.4054651081081644,
#  'transport': 0.4054651081081644,
#  'baltic': 0.0,
#  'sea': 0.0,
#  'commission': 0.0,
#  '22': 0.0,
#  '44': 0.4054651081081644,
#  'lending': 0.4054651081081644,
#  '135': 0.0,
#  'traffic': 0.0,
#  'measured': 1.0986122886681098,
#  'passenger': 0.0,
#  'kilometre': 0.4054651081081644,
#  'rpk': 1.0986122886681098,
#  'went': 0.0,
#  'available': 0.0,
#  'seat': 0.0,
#  'ask': 0.4054651081081644,
#  'januaryseptember': 0.0,
#  'fiskars': 0.0,
#  '14': 0.0,
#  '654': 1.0986122886681098,
#  '5253': 1.0986122886681098,
#  '4877': 1.0986122886681098,
#  '165': 0.4054651081081644,
#  '140': 0.0,
#  '226': 1.0986122886681098,
#  '152': 0.4054651081081644,
#  'nyrstar': 1.0986122886681098,
#  'also': 0.0,
#  'agreed': 0.0,
#  'supply': 0.0,
#  'talvivaara': 0.0,
#  '150000': 0.4054651081081644,
#  'tonne': 0.0,
#  'sulphuric': 1.0986122886681098,
#  'acid': 1.0986122886681098,
#  'annum': 0.4054651081081644,
#  'leaching': 1.0986122886681098,
#  'process': 0.0,
#  'zinc': 0.4054651081081644,
#  'concentrate': 0.4054651081081644,
#  'department': 0.0,
#  'store': 0.0,
#  'hobby': 0.0,
#  'hall': 0.0,
#  'seppala': 0.0,
#  'decreased': 0.0,
#  'export': 0.0,
#  'due': 0.0,
#  'rate': 0.0,
#  'operation': 0.0,
#  'strengthens': 0.4054651081081644,
#  'partnership': 0.4054651081081644,
#  'siemens': 0.0,
#  'network': 0.0,
#  'biohit': 0.0,
#  'healthcare': 0.4054651081081644,
#  'ukbased': 1.0986122886681098,
#  'public': 0.0,
#  'develops': 0.4054651081081644,
#  'liquid': 0.0,
#  'handling': 0.0,
#  'product': 0.0,
#  'diagnostic': 0.0,
#  'test': 0.0,
#  'system': 0.0,
#  'already': 0.0,
#  'carried': 0.0,
#  'lead': 0.0,
#  'reached': 0.0,
#  '1417': 1.0986122886681098,
#  'book': 0.4054651081081644,
#  'stood': 0.0,
#  'bln': 0.0,
#  '242': 0.4054651081081644,
#  'pct': 0.0,
#  'amounting': 0.4054651081081644,
#  '365': 0.0,
#  'mln': 0.0,
#  '5343': 1.0986122886681098,
#  'paper': 0.0,
#  'main': 0.0,
#  'including': 0.0,
#  'publication': 0.4054651081081644,
#  'price': 0.0,
#  'world': 0.0,
#  'second': 0.0,
#  'stainless': 0.4054651081081644,
#  'steel': 0.0,
#  'maker': 0.0,
#  'dec': 0.0,
#  'euro603': 1.0986122886681098,
#  '781': 1.0986122886681098,
#  'euro3': 1.0986122886681098,
#  '33': 0.0,
#  '431': 1.0986122886681098,
#  'euro172': 1.0986122886681098,
#  'euro0': 1.0986122886681098,
#  '94': 0.0,
#  'previous': 0.0,
#  'within': 0.0,
#  'framework': 0.4054651081081644,
#  'initial': 0.0,
#  'sitronics': 1.0986122886681098,
#  'jsc': 0.4054651081081644,
#  'mikron': 1.0986122886681098,
#  'manufacturer': 0.0,
#  'exporter': 0.4054651081081644,
#  'microelectronic': 1.0986122886681098,
#  'component': 0.0,
#  '02': 0.0,
#  'eur10': 0.0,
#  'eur6': 0.0,
#  'abroad': 0.0,
#  '62': 0.0,
#  'country': 0.0,
#  'well': 0.0,
#  'ukraine': 0.4054651081081644,
#  'standard': 0.4054651081081644,
#  'chartered': 0.4054651081081644,
#  'stan': 1.0986122886681098,
#  'ftse': 0.0,
#  '100': 0.0,
#  'royal': 0.0,
#  'bank': 0.0,
#  'scotland': 1.0986122886681098,
#  'rb': 0.4054651081081644,
#  'barclays': 0.4054651081081644,
#  'barc': 0.4054651081081644,
#  'bcs': 0.4054651081081644,
#  '17': 0.0,
#  'corp': 0.0,
#  'thursday': 0.0,
#  'cell': 0.4054651081081644,
#  'phone': 0.0,
#  'thirdquarter': 0.4054651081081644,
#  'global': 0.4054651081081644,
#  'financial': 0.0,
#  'published': 0.0,
#  'friday': 0.0,
#  'seb': 0.0,
#  'soared': 1.0986122886681098,
#  'sek6': 1.0986122886681098,
#  '745': 1.0986122886681098,
#  'bn': 0.0,
#  'sek1': 1.0986122886681098,
#  'proposed': 0.4054651081081644,
#  '50': 0.0,
#  'meanwhile': 0.4054651081081644,
#  'request': 0.4054651081081644,
#  'alma': 0.0,
#  'newspaper': 0.0,
#  'research': 0.4054651081081644,
#  'manager': 0.4054651081081644,
#  'jari': 1.0986122886681098,
#  'kaivooja': 1.0986122886681098,
#  'future': 0.0,
#  'centre': 0.4054651081081644,
#  'turku': 0.0,
#  'school': 0.4054651081081644,
#  'economics': 1.0986122886681098,
#  'drawn': 1.0986122886681098,
#  'scenario': 1.0986122886681098,
#  'national': 0.0,
#  'using': 0.4054651081081644,
#  'model': 0.0,
#  'developed': 0.4054651081081644,
#  'university': 1.0986122886681098,
#  'denver': 1.0986122886681098,
#  'sweden': 0.0,
#  'gallerix': 0.4054651081081644,
#  'accumulated': 1.0986122886681098,
#  'sek': 0.0,
#  'denominated': 1.0986122886681098,
#  'support': 0.0,
#  'developing': 0.0,
#  'fast': 1.0986122886681098,
#  'route': 0.0,
#  'development': 0.0,
#  'application': 0.0,
#  'place': 0.0,
#  'atrium': 0.0,
#  'expand': 0.4054651081081644,
#  'moscow': 0.4054651081081644,
#  'continuation': 0.4054651081081644,
#  'theagreement': 1.0986122886681098,
#  'lemminkainen': 0.0,
#  'whereby': 0.4054651081081644,
#  'cramo': 0.0,
#  'acquired': 0.4054651081081644,
#  'entire': 0.0,
#  'fleet': 0.4054651081081644,
#  'oflemminkainen': 1.0986122886681098,
#  'talo': 1.0986122886681098,
#  'oy': 0.0,
#  'ita': 1.0986122886681098,
#  'ja': 1.0986122886681098,
#  'pohjois': 1.0986122886681098,
#  'suomo': 1.0986122886681098,
#  'asimilar': 0.4054651081081644,
#  'tatu': 1.0986122886681098,
#  'hauhio': 1.0986122886681098,
#  'managing': 0.0,
#  'ofcramo': 1.0986122886681098,
#  'envisaged': 0.4054651081081644,
#  'three': 0.0,
#  'ferryboat': 1.0986122886681098,
#  'option': 0.4054651081081644,
#  'two': 0.0,
#  'confirmed': 0.0,
#  '500': 0.0,
#  '6458': 1.0986122886681098,
#  'june': 0.0,
#  'sold': 0.0,
#  'stake': 0.4054651081081644,
#  'nordstjernan': 1.0986122886681098,
#  'taken': 0.0,
#  'acquire': 0.0,
#  'eqt': 1.0986122886681098,
#  'remaining': 0.4054651081081644,
#  'kesko': 0.0,
#  '28022008': 1.0986122886681098,
#  '0930': 0.4054651081081644,
#  'acquires': 0.4054651081081644,
#  'capital': 0.0,
#  'kaukotelko': 0.4054651081081644,
#  'wholly': 0.0,
#  'owned': 0.0,
#  'sponda': 0.0,
#  '1545': 1.0986122886681098,
#  'syndicated': 0.4054651081081644,
#  'oneyear': 0.4054651081081644,
#  'announcement': 0.0,
#  'july': 0.4054651081081644,
#  'subscription': 0.0,
#  'warrant': 1.0986122886681098,
#  '119': 0.4054651081081644,
#  '850': 1.0986122886681098,
#  'subscribed': 1.0986122886681098,
#  'program': 0.0,
#  'cover': 0.0,
#  'hdo': 1.0986122886681098,
#  'platform': 0.4054651081081644,
#  'ac800': 1.0986122886681098,
#  'cxe880': 1.0986122886681098,
#  'optical': 1.0986122886681098,
#  'fttb': 1.0986122886681098,
#  'node': 1.0986122886681098,
#  'designed': 0.4054651081081644,
#  'forward': 0.4054651081081644,
#  'return': 0.0,
#  'path': 1.0986122886681098,
#  'transmission': 0.4054651081081644,
#  'planned': 0.0,
#  'electricity': 0.4054651081081644,
#  'generation': 0.4054651081081644,
#  '350': 1.0986122886681098,
#  'megawatt': 1.0986122886681098,
#  'mw': 0.4054651081081644,
#  'heat': 0.4054651081081644,
#  'omx': 0.0,
#  '25': 0.0,
#  '092': 1.0986122886681098,
#  '251867': 1.0986122886681098,
#  'cap': 0.0,
#  '091': 1.0986122886681098,
#  '471119': 1.0986122886681098,
#  'car': 0.0,
#  'considerably': 0.0,
#  'influence': 1.0986122886681098,
#  'tire': 0.4054651081081644,
#  'maximum': 0.0,
#  '666104': 1.0986122886681098,
#  'exercising': 1.0986122886681098,
#  'b': 0.0,
#  'issue': 0.0,
#  '391630': 1.0986122886681098,
#  '1566520': 1.0986122886681098,
#  'real': 0.0,
#  'estate': 0.0,
#  'investor': 0.0,
#  'wednesday': 0.0,
#  'march': 0.0,
#  'danske': 0.0,
#  'branch': 1.0986122886681098,
#  '7year': 1.0986122886681098,
#  'eur150m': 0.4054651081081644,
#  'ilmarinen': 1.0986122886681098,
#  'mutual': 0.4054651081081644,
#  'pension': 0.0,
#  'eur50m': 0.4054651081081644,
#  'estonia': 0.0,
#  '36': 0.0,
#  'fell': 0.0,
#  'measure': 0.0,
#  'included': 0.0,
#  'increasing': 0.0,
#  'synergy': 0.4054651081081644,
#  'scale': 0.0,
#  'grimaldi': 0.0,
#  'personnel': 0.0,
#  'adjustment': 0.0,
#  'divestments': 1.0986122886681098,
#  'redelivery': 1.0986122886681098,
#  'excess': 0.0,
#  'tonnage': 1.0986122886681098,
#  'rinkuskiai': 0.4054651081081644,
#  '181': 0.0,
#  '137': 0.4054651081081644,
#  'kauno': 0.4054651081081644,
#  'alus': 0.4054651081081644,
#  'grew': 0.4054651081081644,
#  '143': 0.4054651081081644,
#  '960000': 1.0986122886681098,
#  'telecomworldwire7': 0.4054651081081644,
#  'april': 0.0,
#  '2006tj': 0.4054651081081644,
#  'sell': 0.4054651081081644,
#  'morning': 0.4054651081081644,
#  'digital': 0.4054651081081644,
#  'design': 0.0,
#  'tj': 0.4054651081081644,
#  'selling': 0.4054651081081644,
#  'edita': 0.4054651081081644,
#  '718430': 1.0986122886681098,
#  'series': 0.4054651081081644,
#  'become': 0.0,
#  'subject': 1.0986122886681098,
#  'trading': 0.0,
#  'list': 0.4054651081081644,
#  'together': 0.4054651081081644,
#  'old': 0.4054651081081644,
#  'fuel': 0.4054651081081644,
#  'november': 0.0,
#  'tiimari': 0.0,
#  'operates': 0.4054651081081644,
#  '194': 0.4054651081081644,
#  'six': 0.0,
#  'generated': 0.0,
#  'turnover': 0.0,
#  '765': 1.0986122886681098,
#  'becomes': 0.4054651081081644,
#  'focus': 0.4054651081081644,
#  'supplier': 0.0,
#  'pipettors': 0.4054651081081644,
#  'disposable': 0.4054651081081644,
#  'pipettor': 1.0986122886681098,
#  'tip': 0.4054651081081644,
#  'vwr': 1.0986122886681098,
#  'throughout': 0.4054651081081644,
#  'europe': 0.4054651081081644,
#  'combination': 0.4054651081081644,
#  'enabling': 0.4054651081081644,
#  'complex': 0.4054651081081644,
#  'strengthened': 0.4054651081081644,
#  'limited': 0.4054651081081644,
#  'port': 0.0,
#  'connection': 0.4054651081081644,
#  'getting': 0.4054651081081644,
#  'access': 0.4054651081081644,
#  'wide': 0.4054651081081644,
#  'mediterranean': 1.0986122886681098,
#  'africa': 0.4054651081081644,
#  'north': 0.0,
#  'america': 0.0,
#  'say': 0.0,
#  'uwe': 1.0986122886681098,
#  'bakosch': 1.0986122886681098,
#  'blindspots': 1.0986122886681098,
#  'coming': 0.4054651081081644,
#  'vantage': 1.0986122886681098,
#  'point': 0.0,
#  'allows': 0.0,
#  'investigator': 1.0986122886681098,
#  'see': 0.0,
#  'whole': 0.0,
#  'story': 0.4054651081081644,
#  'high': 0.0,
#  'resolution': 1.0986122886681098,
#  'unbroken': 1.0986122886681098,
#  'video': 0.4054651081081644,
#  'still': 0.0,
#  'expects': 0.0,
#  'slightly': 0.0,
#  'level': 0.0,
#  'adding': 0.4054651081081644,
#  'predictability': 1.0986122886681098,
#  'poor': 0.4054651081081644,
#  'trustworthy': 1.0986122886681098,
#  'forecast': 0.0,
#  'current': 0.0,
#  'kemira': 0.0,
#  'position': 0.4054651081081644,
#  'metal': 0.0,
#  'coating': 0.4054651081081644,
#  'finnlines': 0.0,
#  '5054': 1.0986122886681098,
#  '4735': 1.0986122886681098,
#  'adjusted': 0.0,
#  'change': 0.0,
#  'structure': 0.4054651081081644,
#  'optimize': 1.0986122886681098,
#  'operational': 0.4054651081081644,
#  'efficiency': 0.0,
#  'julia': 1.0986122886681098,
#  'prohaska': 1.0986122886681098,
#  'marketing': 0.0,
#  'communication': 0.0,
#  'invest': 0.4054651081081644,
#  'physical': 0.4054651081081644,
#  'infrastructure': 0.4054651081081644,
#  'provide': 0.4054651081081644,
#  'knowhow': 0.4054651081081644,
#  'science': 0.0,
#  'sunrise': 0.4054651081081644,
#  'valley': 0.4054651081081644,
#  'andrius': 1.0986122886681098,
#  'bagdonas': 1.0986122886681098,
#  'broadband': 0.0,
#  'data': 0.0,
#  'tlt1v': 0.0,
#  'saw': 0.4054651081081644,
#  'jump': 1.0986122886681098,
#  'eur2': 0.0,
#  'eur995': 1.0986122886681098,
#  '000': 0.4054651081081644,
#  'aktia': 0.0,
#  '175': 0.4054651081081644,
#  '82': 0.4054651081081644,
#  'land': 0.0,
#  '48': 0.0,
#  '64': 0.0,
#  '444': 0.4054651081081644,
#  '373': 1.0986122886681098,
#  'vaahto': 0.0,
#  '418': 1.0986122886681098,
#  'accounting': 0.0,
#  '112': 0.4054651081081644,
#  'food': 0.0,
#  'lænnen': 0.4054651081081644,
#  'tehtaat': 0.4054651081081644,
#  'continuing': 0.0,
#  '3491': 1.0986122886681098,
#  '3096': 1.0986122886681098,
#  'individual': 0.4054651081081644,
#  'promotion': 0.4054651081081644,
#  'higherthanexpected': 1.0986122886681098,
#  'many': 0.0,
#  'genesis': 1.0986122886681098,
#  'respectively': 0.0,
#  'eur8': 0.4054651081081644,
#  'circulation': 0.4054651081081644,
#  '70': 0.4054651081081644,
#  '308': 1.0986122886681098,
#  'grow': 0.4054651081081644,
#  '1015': 1.0986122886681098,
#  'annually': 0.4054651081081644,
#  'swedish': 0.0,
#  'experiencing': 1.0986122886681098,
#  'estimated': 0.0,
#  'annual': 0.0,
#  'however': 0.0,
#  'continue': 0.0,
#  'favourable': 1.0986122886681098,
#  'trend': 0.0,
#  'cash': 0.0,
#  'flow': 0.0,
#  'activity': 0.0,
#  'eur121m': 1.0986122886681098,
#  'eur97m': 1.0986122886681098,
#  'lithuania': 0.4054651081081644,
#  '190000': 1.0986122886681098,
#  '70000': 0.4054651081081644,
#  'fourth': 0.0,
#  '10507': 1.0986122886681098,
#  '10270': 1.0986122886681098,
#  '598': 0.4054651081081644,
#  '12444': 1.0986122886681098,
#  'kalmar': 0.4054651081081644,
#  'espana': 1.0986122886681098,
#  '113': 0.0,
#  '148': 1.0986122886681098,
#  'x20ac': 0.0,
#  '402': 0.4054651081081644,
#  '585us': 1.0986122886681098,
#  '401': 1.0986122886681098,
#  'eur655m': 1.0986122886681098,
#  'eur438m': 1.0986122886681098,
#  '255': 1.0986122886681098,
#  'eur59': 1.0986122886681098,
#  'charger': 0.0,
#  'delivered': 0.4054651081081644,
#  '41': 0.0,
#  '659': 1.0986122886681098,
#  'piece': 0.4054651081081644,
#  '936': 1.0986122886681098,
#  '932': 1.0986122886681098,
#  'noted': 0.0,
#  'declined': 0.0,
#  'though': 0.4054651081081644,
#  'mobile': 0.0,
#  'yearago': 0.4054651081081644,
#  '1451': 0.4054651081081644,
#  '83': 0.0,
#  '34': 0.0,
#  '117': 0.0,
#  '5mn': 1.0986122886681098,
#  '28': 0.0,
#  '245': 0.4054651081081644,
#  '230': 0.0,
#  'ramirent': 0.0,
#  'quarterended': 1.0986122886681098,
#  '1287': 1.0986122886681098,
#  '163': 1.0986122886681098,
#  '33percent': 1.0986122886681098,
#  '1246': 1.0986122886681098,
#  'thesecond': 1.0986122886681098,
#  '580': 1.0986122886681098,
#  '743': 1.0986122886681098,
#  '569': 0.4054651081081644,
#  'ruukki': 0.0,
#  'aker': 0.0,
#  'norway': 0.0,
#  'suction': 1.0986122886681098,
#  'anchor': 1.0986122886681098,
#  'kalajoki': 1.0986122886681098,
#  'showed': 0.0,
#  'comparable': 0.0,
#  'eur647m': 1.0986122886681098,
#  'ceo': 0.0,
#  'sakari': 1.0986122886681098,
#  'tamminen': 1.0986122886681098,
#  'magazine': 0.0,
#  'gdp': 1.0986122886681098,
#  'overall': 0.0,
#  'weekly': 0.4054651081081644,
#  'basis': 0.4054651081081644,
#  '40000': 0.4054651081081644,
#  '50000': 0.4054651081081644,
#  '1586': 1.0986122886681098,
#  '414': 0.4054651081081644,
#  'cent': 0.0,
#  '2803': 1.0986122886681098,
#  'end': 0.0,
#  '2691': 1.0986122886681098,
#  'ago': 0.0,
#  'best': 0.0,
#  'major': 0.0,
#  'brewery': 0.0,
#  'domestic': 0.0,
#  '25688': 1.0986122886681098,
#  'litre': 0.4054651081081644,
#  '24592': 1.0986122886681098,
#  'transaction': 0.0,
#  'tecnomens': 1.0986122886681098,
#  'workforse': 1.0986122886681098,
#  'add': 0.4054651081081644,
#  '269': 0.4054651081081644,
#  '1058': 0.4054651081081644,
#  '834': 1.0986122886681098,
#  'rental': 0.4054651081081644,
#  'latvian': 0.0,
#  'priority': 0.4054651081081644,
#  'balance': 0.4054651081081644,
#  'sheet': 0.4054651081081644,
#  'hannu': 0.4054651081081644,
#  'krook': 1.0986122886681098,
#  'yit': 0.0,
#  'building': 0.0,
#  'geographically': 1.0986122886681098,
#  '21': 0.0,
#  'october': 0.0,
#  'fishing': 0.4054651081081644,
#  'tackle': 0.4054651081081644,
#  'rapala': 0.0,
#  'vmc': 0.0,
#  'rap1v': 1.0986122886681098,
#  'eur18': 1.0986122886681098,
#  'nine': 0.0,
#  'eur15': 0.4054651081081644,
#  'bim': 0.4054651081081644,
#  'information': 0.0,
#  'modeling': 0.4054651081081644,
#  'software': 0.0,
#  'tekla': 0.4054651081081644,
#  'modelbased': 1.0986122886681098,
#  'adopted': 1.0986122886681098,
#  'management': 0.0,
#  'project': 0.0,
#  'abu': 1.0986122886681098,
#  'dhabi': 1.0986122886681098,
#  'metso': 0.0,
#  'mineral': 0.4054651081081644,
#  'gone': 0.4054651081081644,
#  ...}
